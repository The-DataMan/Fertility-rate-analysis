# %% [markdown]
# # WE WILL WORK ON REDUCING THE DATA TO ONLY THE SECTIONS WE NEED

# %%
import pandas as pd

# %% [markdown]
# ### As we saw previously the data was split into regional and national info

# %%
import pycountry as pco

# %%
iso3_name_set = {country.alpha_3 for country in pco.countries}
iso3_name_set.add('XKX')

# %%
df = pd.read_csv('../../data/original_data/population-count/population.csv')

# %%
df_countries = df[df['Country Code'].isin(iso3_name_set)]
df_countries.head(10)
# Out:
#             Country Name Country Code     Indicator Name Indicator Code  \
# 0                  Aruba          ABW  Population, total    SP.POP.TOTL
# 2            Afghanistan          AFG  Population, total    SP.POP.TOTL
# 4                 Angola          AGO  Population, total    SP.POP.TOTL
# 5                Albania          ALB  Population, total    SP.POP.TOTL
# 6                Andorra          AND  Population, total    SP.POP.TOTL
# 8   United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 9              Argentina          ARG  Population, total    SP.POP.TOTL
# 10               Armenia          ARM  Population, total    SP.POP.TOTL
# 11        American Samoa          ASM  Population, total    SP.POP.TOTL
# 12   Antigua and Barbuda          ATG  Population, total    SP.POP.TOTL
#
#           1960        1961        1962        1963        1964        1965  \
# 0      54922.0     55578.0     56320.0     57002.0     57619.0     58190.0
# ...

# %%
df[df['Country Name']=='Not classified']
# Out:
#        Country Name Country Code     Indicator Name Indicator Code  1960  \
# 110  Not classified          INX  Population, total    SP.POP.TOTL   NaN
#
#      1961  1962  1963  1964  1965  ...  2017  2018  2019  2020  2021  2022  \
# 110   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2023  2024  2025  Unnamed: 70
# 110   NaN   NaN   NaN          NaN
#
# [1 rows x 71 columns]

# %% [markdown]
# ## Deleting unecessary columns / empty rows

# %%
df_countries.drop(df_countries[df_countries['Country Name']=='Not classified'].index, inplace=True)

# %%
df_countries.drop(df_countries.columns[[2, 3, 69, 70]], axis=1, inplace=True) ## 69,70 ALL Nans 2, 3 duplicated unecessary data

# %%
df_countries.reset_index(drop=True)
df_countries.head(10)
# Out:
#             Country Name Country Code        1960        1961        1962  \
# 0                  Aruba          ABW     54922.0     55578.0     56320.0
# 2            Afghanistan          AFG   9035043.0   9214083.0   9404406.0
# 4                 Angola          AGO   5231654.0   5301583.0   5354310.0
# 5                Albania          ALB   1608800.0   1659800.0   1711319.0
# 6                Andorra          AND      9510.0     10283.0     11086.0
# 8   United Arab Emirates          ARE    131334.0    137989.0    144946.0
# 9              Argentina          ARG  20386045.0  20726276.0  21072538.0
# 10               Armenia          ARM   1863705.0   1927484.0   1991689.0
# 11        American Samoa          ASM     20133.0     20666.0     21298.0
# 12   Antigua and Barbuda          ATG     55603.0     56540.0     57336.0
#
#           1963        1964        1965        1966        1967  ...  \
# 0      57002.0     57619.0     58190.0     58694.0     58990.0  ...
# ...

# %%
df_groups=df[~df['Country Code'].isin(iso3_name_set)]
df_groups.head(10)
# Out:
#                                      Country Name Country Code  \
# 1                     Africa Eastern and Southern          AFE
# 3                      Africa Western and Central          AFW
# 7                                      Arab World          ARB
# 36                 Central Europe and the Baltics          CEB
# 38                                Channel Islands          CHI
# 49                         Caribbean small states          CSS
# 61    East Asia & Pacific (excluding high income)          EAP
# 62                     Early-demographic dividend          EAR
# 63                            East Asia & Pacific          EAS
# 64  Europe & Central Asia (excluding high income)          ECA
#
#        Indicator Name Indicator Code          1960          1961  \
# 1   Population, total    SP.POP.TOTL  1.300757e+08  1.335349e+08
# 3   Population, total    SP.POP.TOTL  9.763092e+07  9.970667e+07
# 7   Population, total    SP.POP.TOTL  9.154085e+07  9.393168e+07
# ...

# %%
df_groups.drop(df_groups[df_groups['Country Name']=='Not classified'].index, inplace=True)

# %%
df_groups.drop(df_groups.columns[[2, 3, 69, 70]], axis=1, inplace=True) ## 69,70 ALL Nans 2, 3 duplicated unecessary data

# %%
df_countries[df_countries['Country Name']=='South Sudan'].T.iloc[40:70]
# Out:
#              215
# 1998   5620068.0
# 1999   5771628.0
# 2000   6032267.0
# 2001   6308391.0
# 2002   6596806.0
# 2003   6903127.0
# 2004   7233041.0
# 2005   7590143.0
# 2006   7976526.0
# 2007   8388788.0
# 2008   8817647.0
# 2009   9243556.0
# 2010   9745953.0
# 2011  10288109.0
# 2012  10756240.0
# 2013  11166275.0
# 2014  11235073.0
# 2015  11107561.0
# 2016  10830102.0
# 2017  10259154.0
# 2018  10122977.0
# 2019  10423384.0
# 2020  10698467.0
# 2021  10865780.0
# 2022  11021177.0
# 2023  11483374.0
# 2024  11943408.0

# %%
df_countries.sum()[2:70] ##vALUES CONSISTENT WITH GROUPS DATA
# Out:
# 1960    3008586057.0
# 1961    3049398996.0
# 1962    3103513758.0
# 1963    3169727675.0
# 1964    3236421104.0
#             ...
# 2020    7821783266.0
# 2021    7887489204.0
# 2022    7956634224.0
# 2023    8030667956.0
# 2024    8108253520.0
# Length: 65, dtype: object

# %%
df_countries.to_csv("../../data/reduced_data/population/population-countries.csv", index=False)

# %%
df_groups.to_csv("../../data/reduced_data/population/population-by-group.csv", index=False)
