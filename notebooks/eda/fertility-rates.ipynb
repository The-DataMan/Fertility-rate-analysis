# %% [markdown]
# ## Understanding and digging for unexpected errors

# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/original_data/fertility-rates/fertility-rate.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 71 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    str
#  1   Country Code    266 non-null    str
#  2   Indicator Name  266 non-null    str
#  3   Indicator Code  266 non-null    str
#  4   1960            264 non-null    float64
#  5   1961            263 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            263 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
print(len(df))
# Out:
# 266

# %%
print(df.head())
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                              Indicator Name  Indicator Code      1960  \
# 0  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  4.567000
# 1  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  6.650310
# 2  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  7.282000
# 3  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  6.468887
# 4  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  6.708000
#
#        1961      1962      1963      1964      1965  ...      2017      2018  \
# 0  4.422000  4.262000  4.107000  3.940000  3.797000  ...  1.785000  1.732000
# 1  6.667308  6.688246  6.709226  6.724930  6.737459  ...  4.569884  4.521443
# ...

# %%
df_ex=df[(df['Indicator Name']!="Fertility rate, total (births per woman)") | (df['Indicator Code']!= 'SP.DYN.TFRT.IN')]
print(df_ex.empty)
# Out:
# True

# %%
df[df.iloc[:, :68].isnull().any(axis=1)]
# Out:
#            Country Name Country Code  \
# 110      Not classified          INX
# 144          Luxembourg          LUX
# 196  West Bank and Gaza          PSE
#
#                                Indicator Name  Indicator Code  1960  1961  \
# 110  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN   NaN   NaN
# 144  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN  2.29   NaN
# 196  Fertility rate, total (births per woman)  SP.DYN.TFRT.IN   NaN   NaN
#
#      1962  1963  1964  1965  ...   2017   2018   2019   2020   2021   2022  \
# 110   NaN   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 144  2.37   NaN  2.34  2.42  ...  1.390  1.380  1.340  1.360  1.380  1.310
# 196   NaN   NaN   NaN   NaN  ...  3.771  3.674  3.591  3.511  3.442  3.375
#
#       2023  2024  2025  Unnamed: 70
# 110    NaN   NaN   NaN          NaN
# 144  1.250   NaN   NaN          NaN
# 196  3.311   NaN   NaN          NaN
#
# [3 rows x 71 columns]

# %%
df_subset = df.iloc[[144,196], :68]

# %%
df_subset.columns[df_subset.isnull().any()].tolist()
# Out:
# ['1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989']
